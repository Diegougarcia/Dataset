# %% [markdown]
# <a href="https://colab.research.google.com/github/Diegougarcia/Dataset/blob/main/act5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
antropometria = pd.read_csv("https://raw.githubusercontent.com/Diegougarcia/Dataset/main/antropometria-dataset-1%20(2).csv")
antropometria.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
subset_data = data['edad']
plt.boxplot(subset_data)
plt.show()

# %%
subset_data = data[data["sexo"] == 1]
median_edad = subset_data["edad"].median()
print("El median de edad en sexo 1:", median_edad)
# Out:
# El median de edad en sexo 1: 28.0

# %%
subset_data = data[data["sexo"] == 2]
cadera_values = subset_data["cadera"]
print("cadera de sexo 2:\n", cadera_values)
# Out:
# cadera de sexo 2:
#  0        106.0
# 1         75.0
# 2         94.3
# 4        127.0
# 6         70.1
#          ...
# 18633    104.1
# 18635    113.0
# 18636    113.7
# 18638     94.8
# 18639    120.0
# Name: cadera, Length: 10486, dtype: float64

# %%
plt.hist(data['peso'], bins=25)
plt.show()

# %%
data_sexo2 = data[data['sexo'] == 2]
ropa_por_estado = data_sexo2.groupby('desc_ent')['ropa'].sum()
ropa_por_estado = ropa_por_estado.sort_values(ascending=False)
plt.barh(ropa_por_estado.index, ropa_por_estado)
plt.show()
